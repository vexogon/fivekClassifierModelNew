# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('categories_settings_balanced_new.csv')
df.head()
# Out:
#                              img_name   setting
# 0        abstract_karel-appel_488.jpg  abstract
# 1     abstract_jose-guerrero_5465.jpg  abstract
# 2       abstract_jimmy-ernst_4123.jpg  abstract
# 3  abstract_ronnie-landfield_7256.jpg  abstract
# 4            abstract_jo-baer_886.jpg  abstract

# %%
#Count of settings by category in bar chart
setting_counts = df['setting'].value_counts()
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='setting', order=setting_counts.index, palette='viridis')
plt.title('Distribution of Settings')
plt.xlabel('Setting')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/ch/bfx06mdj29ndjk1wx8vb4pz00000gn/T/ipykernel_78119/3734854886.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='setting', order=setting_counts.index, palette='viridis')

# %%
#Pie chart of settings by category
plt.figure(figsize=(8, 8))
plt.pie(setting_counts, labels=setting_counts.index, autopct='%1.1f %%', startangle=140) # Pie chart of setting distribution
# setting_counts.index gives the names of the unique values in the 'setting' column
plt.title('Distribution of Settings')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
#drop row with .jpg as img_name
df = df[df['img_name'] != '.jpg']
df.to_csv('categories_settings_balanced_new.csv', index=False)

# %%
#corrupted image
df = df[df['img_name'] != 'events.jpg']
df.to_csv('categories_settings_balanced_new.csv', index=False)
